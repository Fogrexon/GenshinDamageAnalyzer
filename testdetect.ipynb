# %%
from video_controller import VideoController
from analyze_video import analyze_video

# %%
controller = VideoController("videos/rasen.mp4")
analyze_video(controller, "cyro", lambda x:x)
# Out:
# {'fps': 30.0, 'frame_count': 675.0, 'frame_width': 1920.0, 'frame_height': 1080.0, 'damage_dropout': 7, 'enemy_dropout': 15, 'damages': [{'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 15781, 'damages': [{'number': 15781, 'rect': [966, 354, 144, 52]}]}, {'total': 86906, 'damages': [{'number': 86906, 'rect': [704, 172, 176, 52]}]}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 0, 'damages': []}, {'total': 28245, 'damages': [{'numbe
# ...
